# %%
print("Helllow World")
# Out:
# Helllow World

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
with open('example.txt', 'r', encoding='utf-8') as f:
    for line in f.read():
        print(line)
# Out:
# L
# o
# r
# e
# m
#
# i
# p
# s
# u
# m
#
# d
# o
#
#
# l
# o
# r
#
# s
# i
# t
#
# a
# m
# e
# t
#
# c
# o
# n
# s
# e
# c
# t
# e
# t
# u
# r
#
# a
# d
# i
# p
# i
# s
# i
# c
# i
# n
# g
#
# e
# l
# i
# t
# .
#
# A
# c
# c
# u
# s
# a
# n
# t
#
#
# i
# u
# m
#
# d
# e
# b
# i
# t
# i
# s
#
# a
# s
# p
# e
# r
# n
# a
# t
# u
# r
#
# r
# e
# i
# c
# i
# e
# n
# d
# i
# s
#
# e
# s
# t
# .
#
# M
# i
# n
# u
# s
#
# p
# o
# r
# r
# o
#
# p
# l
# a
# c
# e
# a
# t
#
# e
# a
#
# s
# a
# e
# p
# e
#
# q
# u
# i
#
#
# d
# e
# m
#
# v
# i
# t
# a
# e
#
# e
# s
# s
# e
#
# n
# u
# m
# q
# u
# a
# m
#
# i
# t
# a
# q
# u
# e
# ,
#
# s
# e
# d
#
# f
# u
# g
# i
# a
# t
#
# r
# e
# r
# u
# m
# ,
#
# l
# a
# b
# o
# r
# u
# m
#
# o
# f
# f
# i
# c
# i
# a
#
# t
# o
# t
# a
# m
# .
#
# R
# e
# m
#
# n
#
#
# a
# t
# u
# s
#
# a
# c
# c
# u
# s
# a
# n
# t
# i
# u
# m
# ,
#
# s
# a
# p
# i
# e
# n
# t
# e
#
# a
# r
# c
# h
# i
# t
# e
# c
# t
# o
# ,
#
# d
# o
# l
# o
# r
# e
# m
# q
# u
# e
#
# ...
