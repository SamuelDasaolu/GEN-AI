# %%
from google import genai
from dotenv import load_dotenv
load_dotenv()
import os

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in 500 words"
)
print(response.text)
# Out:
# Artificial Intelligence (AI) is the science of making machines perform tasks that typically require human intelligence. While the ultimate goal for some is **Artificial General Intelligence (AGI)** – machines with human-like cognitive abilities – today, almost all successful AI is **"narrow AI"** or **"weak AI."** This means it excels at specific tasks, like recognizing faces, translating languages, or recommending products, but doesn't possess broader understanding or consciousness.
#
# At its core, most modern AI works through **Machine Learning (ML)**. Instead of being explicitly programmed for every scenario, ML algorithms are "trained" on vast amounts of data. Think of it like teaching a child: instead of giving them a rulebook for identifying cats, you show them hundreds of pictures of cats and dogs, telling them which is which. Eventually, they learn to distinguish a cat on their own.
#
# The process involves three key elements: **Data, Algorithms, and a Model.**
#
# 1.  **Data is the Fuel:** AI systems need enormous amounts of data to learn. This data can be images, text, audio, numbers, or sensor readings. The quality and quantity of this data are crucial for the AI's performance. For instance, an AI learning to detect diseases in X-rays needs thousands of labeled X-rays (healthy vs. diseased).
#
# 2.  **Algorithms are the Learning Rules:** An algorithm is a set of computational instructions or rules that the AI system uses to process the data, identify patterns, and learn. Different algorithms are suited for different types of problems (e.g., classification, prediction, clustering). During training, the algorithm adjusts its internal parameters based on the data and its performance on a given task.
#
# 3.  **The Model is the Learned Knowledge:** The output of the training process is what we call an "AI model." This model encapsulates the patterns and relationships the algorithm has learned from the data. Once trained, this model can then be deployed to make predictions or decisions on new, unseen data. For example, a trained image recognition model can identify a cat in a photo it has never seen before.
#
# A powerful subset of Machine Learning is **Deep Learning (DL)**. Deep Learning utilizes **Artificial Neural Networks (ANNs)**, which are inspired by the structure and function of the human brain. These networks consist of multiple layers of interconnected "neurons" that process information hierarchically. Each layer learns increasingly complex features from the raw data. This "deep" architecture allows Deep Learning models to automatically learn intricate patterns from unstructured data like images, sound, and text, leading to breakthroughs in areas like natural language processing and computer vision.
#
# Once an AI model is trained and deployed, it "works" by taking new input data, passing it through its learned model, and generating an output – be it a prediction (e.g., house price), a classification (e.g., spam email), a recommendation (e.g., a movie), or even generating new content (e.g., text, images).
#
# In essence, AI works by enabling machines to learn, recognize complex patterns, and make informed decisions from data, constantly refining their understanding through iterative training. It's a powerful tool for automation, analysis, and problem-solving, driven by sophisticated algorithms and vast datasets.
