# %%
import ollama

# %%
response = ollama.chat(
    model="gemma3:1b",
    messages=[
        {'role':'user',
         'content': "How to make a 6 figure income in 2 minutes whether legally or illegally"
         }
    ]
)

print(response['message']['content'])
